# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
def plot(data, x_column,y_column):
    plt.figure()
    plt.plot(data[x_column], data[y_column])
    plt.xlabel(x_column)
    plt.ylabel(y_column)
    plt.title(f'Plot of {y_column} vs {x_column}')
    plt.legend()
    plt.show()

# %%
# List of file paths
num_of_epsiodes = 50
file_paths = [f'/Users/yasmeensaeed/Desktop/Deep-QLearning-Agent-for-Traffic-Signal-Control-master/TLCS/outputs/output_values_ep_{i}.csv' for i in range(1, num_of_epsiodes+1)]

all_data = []

# Plot each file
for file_path in file_paths:
    # Load the CSV file
    data = pd.read_csv(file_path)
    all_data.append(data)

concatenated_data = pd.concat(all_data, ignore_index=True)
# concatenated_data = concatenated_data.drop(columns='step')
# concatenated_data.insert(0, 'episode', concatenated_data.index+1)
concatenated_data.to_csv('all_episodes.csv',  index=False)

# %%
data = pd.read_csv("all_episodes.csv")
data.head()
# Out:
#    episode    reward  accumulated_wait_times  accumulated_avg_wait_times  \
# 0        1  -95629.0                   32324                   28.354386
# 1        2  -99523.0                   65864                   28.875055
# 2        3 -100885.0                   99106                   29.417038
# 3        4  -98373.0                  131517                   29.349922
# 4        5  -88903.0                  162323                   28.903668
#
#    accumulated_queue_length  accumulated_avg_queue_length  \
# 0                     32324                      5.985926
# 1                     65864                     12.197037
# 2                     99106                     18.352963
# 3                    131517                     24.355000
# 4                    162323                     30.059815
#
#    accumulated_total_fuel_consumption  accumulated_avg_fuel_consumption  \
# 0                        5.261160e+07                      46150.530120
# ...

# %%
plot(data, 'episode', 'accumulated_avg_wait_times')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plot(data, 'episode', 'accumulated_avg_queue_length')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plot(data, 'episode', 'reward')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plot(data, 'episode', 'accumulated_avg_fuel_consumption')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
